# %%
import pandas as pd
import sqlite3

# 1.1

with sqlite3.connect('data/chinook.db') as con:
    df_chinook = pd.read_sql_query("SELECT * FROM customers", con)


print(df_chinook.head(10))
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# 9                                  Woodstock Discos
#
#                                 Address                 City State  \
# 0       Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP
# 1               Theodor-Heuss-Straße 34            Stuttgart  None
# 2                     1498 rue Bélanger             Montréal    QC
# 3                      Ullevålsveien 14                 Oslo  None
# 4                         Klanova 9/506               Prague  None
# 5                         Rilská 3174/6               Prague  None
# 6  Rotenturmstraße 4, 1010 Innere Stadt               Vienne  None
# 7                       Grétrystraat 63             Brussels  None
# 8                   Sønder Boulevard 51           Copenhagen  None
# 9             Rua Dr. Falcão Filho, 155            São Paulo    SP
#
#           Country PostalCode               Phone                 Fax  \
# 0          Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1         Germany      70174    +49 0711 2842222                None
# 2          Canada    H2G 1A7   +1 (514) 721-4711                None
# 3          Norway       0171     +47 22 44 22 22                None
# 4  Czech Republic      14700    +420 2 4172 5555    +420 2 4172 5555
# 5  Czech Republic      14300    +420 2 4177 0449                None
# 6         Austria       1010      +43 01 5134505                None
# 7         Belgium       1000    +32 02 219 03 03                None
# 8         Denmark       1720      +453 3331 9991                None
# 9          Brazil  01007-010  +55 (11) 3033-5446  +55 (11) 3033-4564
#
#                       Email  SupportRepId
# 0      luisg@embraer.com.br             3
# 1     leonekohler@surfeu.de             5
# 2       ftremblay@gmail.com             3
# 3     bjorn.hansen@yahoo.no             4
# 4  frantisekw@jetbrains.com             4
# 5           hholy@gmail.com             5
# 6    astrid.gruber@apple.at             5
# 7     daan_peeters@apple.be             4
# 8     kara.nielsen@jubii.dk             4
# 9  eduardo@woodstock.com.br             4

# %%
# 1.2

import json

with open("data/iris.json") as f:
    data = json.load(f)

df_iris = pd.DataFrame(data)

print(df_iris.shape)
print(df_iris.columns)
# Out:
# (150, 5)
# Index(['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species'], dtype='object')

# %%
# 1.3

df_titanic = pd.read_excel("data/titanic.xlsx")
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 1.4

df_flights = pd.read_parquet('data/flights')
df_flights.info()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 # 1.4
# ----> 3 df_flights = pd.read_parquet('data/flights')
#       4 df_flights.info()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parquet.py:281, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
# --> 281     result = pa_table.to_pandas(**to_pandas_kwargs)
#     283     if manager == "array":
#     284         result = result._as_manager("array", copy=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyarrow\array.pxi:889, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyarrow\table.pxi:5132, in pyarrow.lib.Table._to_pandas()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyarrow\pandas_compat.py:808, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     805 columns = _deserialize_column_index(table, all_columns, column_indexes)
#     807 column_names = table.column_names
# --> 808 result = pa.lib.table_to_blocks(options, table, categories,
#     809                                 list(ext_columns_dtypes.keys()))
#     810 if _pandas_api.is_ge_v3():
#     811     from pandas.api.internals import create_dataframe_from_blocks
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyarrow\table.pxi:4061, in pyarrow.lib.table_to_blocks()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyarrow\error.pxi:89, in pyarrow.lib.check_status()
#
# MemoryError: Unable to allocate 5.46 GiB for an array with shape (109, 6729125) and data type object

# %%
# 1.5

df_movie = pd.read_csv("data/movie.csv")
df_movie.sample(10)
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 2054  Color              Mira Nair                   118.0     141.0
# 4662  Color         Catherine Gund                    10.0      82.0
# 1401  Color  Kevin Rodney Sullivan                   104.0     105.0
# 4786  Color            Stevan Mena                    60.0      90.0
# 3735  Color           Jim Amatulli                     NaN      90.0
# 1946  Color        Luke Greenfield                   126.0     110.0
# 3491  Color              Alan Alda                     6.0     107.0
# 4039  Color            Deon Taylor                    63.0      88.0
# 2566  Color          Leonard Nimoy                    21.0     102.0
# 3245  Color      Michael O. Sajbel                    46.0     114.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 2054                    300.0                    73.0  Roger Lloyd Pack
# 4662                      0.0                     0.0      Sarah Callan
# 1401                      8.0                   278.0   Nicole Sullivan
# 4786                     25.0                    10.0       Stevan Mena
# 3735                      0.0                   483.0     Patricia Neal
# 1946                     42.0                   111.0   Timothy Bottoms
# 3491                      0.0                   146.0        Len Cariou
# 4039                     26.0                   236.0     Betsy Russell
# 2566                  12000.0                   801.0        Ted Danson
# 3245                      6.0                   633.0       Drew Fuller
#
#       actor_1_facebook_likes        gross                              genres  \
# 2054                   805.0   16123851.0                               Drama
# 4662                     0.0      21199.0  Action|Biography|Documentary|Sport
# 1401                  1000.0   67962333.0                      Comedy|Romance
# 4786                   169.0          NaN       Crime|Horror|Mystery|Thriller
# 3735                   695.0          NaN                  Drama|Family|Music
# 1946                   355.0   14589444.0                Comedy|Drama|Romance
# 3491                   804.0          NaN                        Comedy|Drama
# 4039                   487.0     143000.0                     Horror|Thriller
# 2566                 19000.0  167780960.0                 Comedy|Drama|Family
# 3245                   970.0    3420871.0                Drama|Family|Romance
#
#       ... num_user_for_reviews language  country  content_rating      budget  \
# 2054  ...                148.0  English      USA           PG-13  23000000.0
# 4662  ...                 10.0  English      USA             NaN    500000.0
# 1401  ...                160.0  English      USA           PG-13  35000000.0
# 4786  ...                112.0  English      USA               R    200000.0
# 3735  ...                  2.0  English      USA           PG-13         NaN
# 1946  ...                513.0  English      USA               R  25000000.0
# 3491  ...                 33.0  English      USA              PG         NaN
# 4039  ...                 48.0  English      USA               R   5000000.0
# 2566  ...                 42.0  English      USA              PG  11000000.0
# 3245  ...                 81.0  English      USA              PG         NaN
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 2054      2004.0                  539.0        6.2          2.35
# 4662      2014.0                    0.0        6.8           NaN
# 1401      2005.0                  358.0        5.9          1.85
# 4786      2003.0                   25.0        5.1          1.33
# 3735      2009.0                  617.0        4.5           NaN
# 1946      2004.0                  155.0        6.8          1.85
# 3491      1981.0                  167.0        7.2          1.85
# 4039      2009.0                  298.0        4.1          2.35
# 2566      1987.0                  875.0        5.9          1.85
# 3245      2006.0                  906.0        7.4          1.85
#
#      movie_facebook_likes
# 2054                  767
# 4662                   44
# 1401                  919
# 4786                  198
# 3735                   38
# 1946                    0
# 3491                  337
# 4039                    0
# 2566                 3000
# 3245                    0
#
# [10 rows x 28 columns]

# %%
# 2.1

df_iris.columns = df_iris.columns.str.lower()

df_iris[['sepallength', 'sepalwidth']]
# Out:
#      sepallength  sepalwidth
# 0            5.1         3.5
# 1            4.9         3.0
# 2            4.7         3.2
# 3            4.6         3.1
# 4            5.0         3.6
# ..           ...         ...
# 145          6.7         3.0
# 146          6.3         2.5
# 147          6.5         3.0
# 148          6.2         3.4
# 149          5.9         3.0
#
# [150 rows x 2 columns]

# %%
# 2.2

print(df_titanic[df_titanic["Age"] > 30])
print(df_titanic.value_counts("Sex"))
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 4        0    373450   8.0500   NaN        S
# 6        0     17463  51.8625   E46        S
# 11       0    113783  26.5500  C103        S
# ..     ...       ...      ...   ...      ...
# 873      0    345765   9.0000   NaN        S
# 879      1     11767  83.1583   C50        C
# 881      0    349257   7.8958   NaN        S
# 885      5    382652  29.1250   NaN        Q
# 890      0    370376   7.7500   NaN        Q
#
# [305 rows x 12 columns]
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# 2.3

new_columns1 = [column.lower() for column in df_flights.columns]
df_flights.columns = new_columns1
extract = df_flights[["origin", "dest"]]
unique = extract["dest"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # 2.3
# ----> 3 new_columns1 = [column.lower() for column in df_flights.columns]
#       4 df_flights.columns = new_columns1
#       5 extract = df_flights[["origin", "dest"]]
#
# NameError: name 'df_flights' is not defined

# %%
# 2.4


filtered_data = df_movie[df_movie["duration"]> 120]
filtered_data = filtered_data.sort_values(by=["director_facebook_likes"], ascending=False)

# %%
# 3.1

numeric_columns = df_iris.select_dtypes("number")
print(numeric_columns.mean())
print(numeric_columns.median())
print(numeric_columns.std())
# Out:
# sepallength    0.828066
# sepalwidth     0.435866
# petallength    1.765298
# petalwidth     0.762238
# dtype: float64

# %%
# 3.2

print(df_titanic[["Age"]].min())
print(df_titanic[["Age"]].max())
print(df_titanic[["Age"]].sum())
# Out:
# Age    0.42
# dtype: float64
# Age    80.0
# dtype: float64
# Age    21205.17
# dtype: float64

# %%
# 3.3

print(filtered_data.head(1))
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 66  Color  Christopher Nolan                   645.0     152.0
#
#     director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 66                  22000.0                 11000.0  Heath Ledger
#
#     actor_1_facebook_likes        gross                       genres  ...  \
# 66                 23000.0  533316061.0  Action|Crime|Drama|Thriller  ...
#
#    num_user_for_reviews language  country  content_rating       budget  \
# 66               4667.0  English      USA           PG-13  185000000.0
#
#     title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 66      2008.0                13000.0        9.0          2.35
#
#    movie_facebook_likes
# 66                37000
#
# [1 rows x 28 columns]

# %%
# 3.4

missing_values = df_flights.isnull().sum()
missing_values
for column in df_flights.select_dtypes("number").columns:
    df_flights[df_flights[column].isna()] = df_flights[column].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # 3.4
# ----> 3 missing_values = df_flights.isnull().sum()
#       4 missing_values
#       5 for column in df_flights.select_dtypes("number").columns:
#
# NameError: name 'df_flights' is not defined
